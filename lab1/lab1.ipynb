# %% [markdown]
# #Machine learning - lab1

# %%
#Ex. 1 - Data import
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
df1 = pd.DataFrame(iris.data, columns=iris.feature_names)
df1['target'] = iris.target
print(df1.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#Ex. 2 - Data cleanup
missing_data1 = df1.isnull().sum()
print("Brakujace dane: ")
print(missing_data1)

df1_cleaned = df1.dropna()
# Out:
# Brakujace dane:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
#Ex. 3 - Data Visualization
import matplotlib.pyplot as plt

def scatter_plot(data, par1, par2, dataset):
    plt.figure(figsize=(8,6))
    for species in data['target'].unique():
        subset = data[data['target'] == species]
        plt.scatter(subset[par1], subset[par2],
        label = dataset.target_names[species])
    plt.xlabel(par1)
    plt.ylabel(par2)
    plt.legend()
    plt.show()
    
scatter_plot(df1_cleaned, 'sepal length (cm)', 'sepal width (cm)', iris)
scatter_plot(df1_cleaned, 'petal length (cm)', 'petal width (cm)', iris)

# %%
#Ex. 4 - Class size

def counts(data):
    counts = data.value_counts()
    print(counts)

counts(df1['target'])
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
#Ex. 5 - Histograms

def histogram(feature, data):
    plt.figure(figsize=(8,6))
    plt.hist(data[feature], bins=20, edgecolor='k')
    plt.xlabel(feature)
    plt.ylabel('Liczba Próbek')
    plt.title(f'Histogram {feature}')
    plt.show()

histogram("sepal length (cm)", df1)
histogram('target', df1)

# %% [markdown]
# Different Dataset

# %%
#Ex. 1
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
df2 = pd.DataFrame(cancer.data, columns=cancer.feature_names)
df2['target'] = cancer.target

print(df2.head())
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
#Ex. 2

missing_data2 = df2.isnull().sum()
print("Brakujace dane: ")
print(missing_data2)
df2_cleaned = df2.dropna()
# Out:
# Brakujace dane:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %%
#Ex. 3

scatter_plot(df2_cleaned, 'mean radius', 'mean texture', cancer)
scatter_plot(df2_cleaned, 'mean area', 'mean smoothness', cancer)

# %%
#Ex. 4

counts(df2['target'])
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
#Ex. 5

histogram("mean radius", df2)
histogram("target",df2)
